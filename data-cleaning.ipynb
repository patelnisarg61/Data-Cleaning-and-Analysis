# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### LOADING CSV FILE

# %%
weather=pd.read_csv('C:/Users/patel/Downloads/weather.csv', encoding='latin1')
weather.fillna("")
# Out:
#       Date/Time  Year  Month  Day Data Quality Max Temp (Â°C) Max Temp Flag  \
# 0      1/1/2017  2017      1    1                         3.1
# 1      1/2/2017  2017      1    2                         5.5
# 2      1/3/2017  2017      1    3                         4.8
# 3      1/4/2017  2017      1    4                         3.8
# 4      1/5/2017  2017      1    5                        -5.3
# ..          ...   ...    ...  ...          ...            ...           ...
# 360  12/27/2017  2017     12   27                        -9.9
# 361  12/28/2017  2017     12   28                       -11.8
# 362  12/29/2017  2017     12   29                        -7.3
# 363  12/30/2017  2017     12   30                        -6.8
# 364  12/31/2017  2017     12   31                       -13.7
#
#     Min Temp (Â°C) Min Temp Flag Mean Temp (Â°C)  ... Total Snow (cm)  \
# 0             -0.5                           1.3  ...
# 1              0.7                           3.1  ...
# 2              2.4                           3.6  ...
# 3             -7.6                          -1.9  ...
# 4            -10.3                          -7.8  ...
# ..             ...           ...             ...  ...             ...
# 360          -17.9                         -13.9  ...
# 361          -19.6                         -15.7  ...
# 362          -14.3                         -10.8  ...
# 363          -18.1                         -12.5  ...
# 364          -20.2                           -17  ...
#
#     Total Snow Flag Total Precip (mm) Total Precip Flag Snow on Grnd (cm)  \
# 0                 M                 0                                   3
# 1                 M                 0                                   3
# 2                 M              11.3                                   1
# 3                 M               0.6
# 4                 M                 0
# ..              ...               ...               ...               ...
# 360               M                 0                                  11
# 361               M               0.2                                  10
# 362               M                 1                                  10
# 363               M               0.2                                  10
# 364               M                 0                                  11
#
#     Snow on Grnd Flag Dir of Max Gust (10s deg) Dir of Max Gust Flag  \
# 0                                                                  M
# 1                                                                  M
# 2                                                                  M
# 3                                                                  M
# 4                                                                  M
# ..                ...                       ...                  ...
# 360                                                                M
# 361                                                                M
# 362                                                                M
# 363                                                                M
# 364                                                                M
#
#     Spd of Max Gust (km/h) Spd of Max Gust Flag
# 0                                             M
# 1                                             M
# 2                                             M
# 3                                             M
# 4                                             M
# ..                     ...                  ...
# 360                                           M
# 361                                           M
# 362                                           M
# 363                                           M
# 364                                           M
#
# [365 rows x 27 columns]

# %% [markdown]
# ### CHECKING FIRST FIVE ITEMS/ ROWS OF DATA SET

# %%
weather.head()
# Out:
#   Date/Time  Year  Month  Day  Data Quality  Max Temp (Â°C) Max Temp Flag  \
# 0  1/1/2017  2017      1    1           NaN             3.1           NaN
# 1  1/2/2017  2017      1    2           NaN             5.5           NaN
# 2  1/3/2017  2017      1    3           NaN             4.8           NaN
# 3  1/4/2017  2017      1    4           NaN             3.8           NaN
# 4  1/5/2017  2017      1    5           NaN            -5.3           NaN
#
#    Min Temp (Â°C) Min Temp Flag  Mean Temp (Â°C)  ... Total Snow (cm)  \
# 0            -0.5           NaN              1.3  ...             NaN
# 1             0.7           NaN              3.1  ...             NaN
# 2             2.4           NaN              3.6  ...             NaN
# 3            -7.6           NaN             -1.9  ...             NaN
# 4           -10.3           NaN             -7.8  ...             NaN
#
#    Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                M               0.0                NaN               3.0
# 1                M               0.0                NaN               3.0
# 2                M              11.3                NaN               1.0
# 3                M               0.6                NaN               NaN
# 4                M               0.0                NaN               NaN
#
#    Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                NaN                       NaN                     M
# 1                NaN                       NaN                     M
# 2                NaN                       NaN                     M
# 3                NaN                       NaN                     M
# 4                NaN                       NaN                     M
#
#   Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                    NaN                     M
# 1                    NaN                     M
# 2                    NaN                     M
# 3                    NaN                     M
# 4                    NaN                     M
#
# [5 rows x 27 columns]

# %% [markdown]
# ### CHECKING FOR "NA" VALUES

# %%
weather.isna().head()
# Out:
#    Date/Time   Year  Month    Day  Data Quality  Max Temp (Â°C)  \
# 0      False  False  False  False          True           False
# 1      False  False  False  False          True           False
# 2      False  False  False  False          True           False
# 3      False  False  False  False          True           False
# 4      False  False  False  False          True           False
#
#    Max Temp Flag  Min Temp (Â°C)  Min Temp Flag  Mean Temp (Â°C)  ...  \
# 0           True           False           True            False  ...
# 1           True           False           True            False  ...
# 2           True           False           True            False  ...
# 3           True           False           True            False  ...
# 4           True           False           True            False  ...
#
#    Total Snow (cm)  Total Snow Flag  Total Precip (mm)  Total Precip Flag  \
# 0             True            False              False               True
# 1             True            False              False               True
# 2             True            False              False               True
# 3             True            False              False               True
# 4             True            False              False               True
#
#    Snow on Grnd (cm)  Snow on Grnd Flag  Dir of Max Gust (10s deg)  \
# 0              False               True                       True
# 1              False               True                       True
# 2              False               True                       True
# 3               True               True                       True
# 4               True               True                       True
#
#    Dir of Max Gust Flag  Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                 False                    True                 False
# 1                 False                    True                 False
# 2                 False                    True                 False
# 3                 False                    True                 False
# 4                 False                    True                 False
#
# [5 rows x 27 columns]

# %% [markdown]
# # EXPLORATORY ANALYSIS

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(weather.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ### CALCULATING NUMBER OF ITEMS IN A EVERY COLUMN

# %%
weather.isnull().values.any()
# Out:
# True

# %%
weather.isnull().sum().sum()
# Out:
# 4657

# %%
weather.count()
# Out:
# Date/Time                    365
# Year                         365
# Month                        365
# Day                          365
# Data Quality                   0
# Max Temp (Â°C)               357
# Max Temp Flag                 10
# Min Temp (Â°C)               361
# Min Temp Flag                 10
# Mean Temp (Â°C)              355
# Mean Temp Flag                10
# Heat Deg Days (Â°C)          355
# Heat Deg Days Flag            10
# Cool Deg Days (Â°C)          355
# Cool Deg Days Flag            10
# Total Rain (mm)                0
# Total Rain Flag              365
# Total Snow (cm)                0
# Total Snow Flag              365
# Total Precip (mm)            350
# Total Precip Flag             15
# Snow on Grnd (cm)             60
# Snow on Grnd Flag             20
# Dir of Max Gust (10s deg)      0
# Dir of Max Gust Flag         365
# Spd of Max Gust (km/h)         0
# Spd of Max Gust Flag         365
# dtype: int64

# %%
weather.isnull().sum()
# Out:
# Date/Time                      0
# Year                           0
# Month                          0
# Day                            0
# Data Quality                 365
# Max Temp (Â°C)                 8
# Max Temp Flag                355
# Min Temp (Â°C)                 4
# Min Temp Flag                355
# Mean Temp (Â°C)               10
# Mean Temp Flag               355
# Heat Deg Days (Â°C)           10
# Heat Deg Days Flag           355
# Cool Deg Days (Â°C)           10
# Cool Deg Days Flag           355
# Total Rain (mm)              365
# Total Rain Flag                0
# Total Snow (cm)              365
# Total Snow Flag                0
# Total Precip (mm)             15
# Total Precip Flag            350
# Snow on Grnd (cm)            305
# Snow on Grnd Flag            345
# Dir of Max Gust (10s deg)    365
# Dir of Max Gust Flag           0
# Spd of Max Gust (km/h)       365
# Spd of Max Gust Flag           0
# dtype: int64

# %% [markdown]
# ### DROPPING EMPTY COLUMNS

# %%
to_drop = ['Dir of Max Gust (10s deg)', 'Total Snow (cm)', 'Total Rain (mm)']
weather.drop(to_drop, inplace=True, axis=1)
to_drop = ['Spd of Max Gust (km/h)']
weather.drop(to_drop, inplace=True, axis=1)
weather.head()
# Out:
#   Date/Time  Year  Month  Day  Data Quality  Max Temp (Â°C) Max Temp Flag  \
# 0  1/1/2017  2017      1    1           NaN             3.1           NaN
# 1  1/2/2017  2017      1    2           NaN             5.5           NaN
# 2  1/3/2017  2017      1    3           NaN             4.8           NaN
# 3  1/4/2017  2017      1    4           NaN             3.8           NaN
# 4  1/5/2017  2017      1    5           NaN            -5.3           NaN
#
#    Min Temp (Â°C) Min Temp Flag  Mean Temp (Â°C)  ... Cool Deg Days (Â°C)  \
# 0            -0.5           NaN              1.3  ...                 0.0
# 1             0.7           NaN              3.1  ...                 0.0
# 2             2.4           NaN              3.6  ...                 0.0
# 3            -7.6           NaN             -1.9  ...                 0.0
# 4           -10.3           NaN             -7.8  ...                 0.0
#
#    Cool Deg Days Flag Total Rain Flag  Total Snow Flag Total Precip (mm)  \
# 0                 NaN               M                M               0.0
# 1                 NaN               M                M               0.0
# 2                 NaN               M                M              11.3
# 3                 NaN               M                M               0.6
# 4                 NaN               M                M               0.0
#
#   Total Precip Flag Snow on Grnd (cm)  Snow on Grnd Flag Dir of Max Gust Flag  \
# 0               NaN               3.0                NaN                    M
# 1               NaN               3.0                NaN                    M
# 2               NaN               1.0                NaN                    M
# 3               NaN               NaN                NaN                    M
# 4               NaN               NaN                NaN                    M
#
#    Spd of Max Gust Flag
# 0                     M
# 1                     M
# 2                     M
# 3                     M
# 4                     M
#
# [5 rows x 23 columns]

# %%
to_drop = ['Data Quality']
weather.drop(to_drop, inplace=True, axis=1)
weather.head()
# Out:
#   Date/Time  Year  Month  Day  Max Temp (Â°C) Max Temp Flag  Min Temp (Â°C)  \
# 0  1/1/2017  2017      1    1             3.1           NaN            -0.5
# 1  1/2/2017  2017      1    2             5.5           NaN             0.7
# 2  1/3/2017  2017      1    3             4.8           NaN             2.4
# 3  1/4/2017  2017      1    4             3.8           NaN            -7.6
# 4  1/5/2017  2017      1    5            -5.3           NaN           -10.3
#
#   Min Temp Flag  Mean Temp (Â°C) Mean Temp Flag  ...  Cool Deg Days (Â°C)  \
# 0           NaN              1.3            NaN  ...                  0.0
# 1           NaN              3.1            NaN  ...                  0.0
# 2           NaN              3.6            NaN  ...                  0.0
# 3           NaN             -1.9            NaN  ...                  0.0
# 4           NaN             -7.8            NaN  ...                  0.0
#
#   Cool Deg Days Flag  Total Rain Flag Total Snow Flag Total Precip (mm)  \
# 0                NaN                M               M               0.0
# 1                NaN                M               M               0.0
# 2                NaN                M               M              11.3
# 3                NaN                M               M               0.6
# 4                NaN                M               M               0.0
#
#   Total Precip Flag  Snow on Grnd (cm) Snow on Grnd Flag  \
# 0               NaN                3.0               NaN
# 1               NaN                3.0               NaN
# 2               NaN                1.0               NaN
# 3               NaN                NaN               NaN
# 4               NaN                NaN               NaN
#
#    Dir of Max Gust Flag Spd of Max Gust Flag
# 0                     M                    M
# 1                     M                    M
# 2                     M                    M
# 3                     M                    M
# 4                     M                    M
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(weather.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ### COMPLETING FLAGS

# %% [markdown]
# REFERENCE FOR FLAGS: https://learn.weatherstem.com/modules/learn/lessons/27/12.html

# %%
#SIngle condition : weather['Max Temp Flag'] = np.where(weather['Max Temp (°C)'] >33.3, 'Green',weather['Max Temp Flag'])
conditions  = [ weather.iloc[:,5] >33.3, (weather.iloc[:,5] <=33.3) & (weather.iloc[:,5] >=32.3), (weather.iloc[:,5] <32.3) & (weather.iloc[:,5] >=30.5), (weather.iloc[:,5] <30.5) & (weather.iloc[:,5] >=27.8), weather.iloc[:,5] <27.8 ]
choices     = [ "Black", 'Red', 'Yellow', 'Green', 'White']

weather['Max Temp Flag'] = np.select(conditions, choices, default=np.nan)

weather['Max Temp Flag'].value_counts()
# Out:
# White     332
# Green      19
# nan         8
# Yellow      6
# Name: Max Temp Flag, dtype: int64

# %%
sns.countplot(x='Max Temp Flag', data=weather)

# %%
conditions  = [ weather.iloc[:,7] >33.3, (weather.iloc[:,7] <=33.3) & (weather.iloc[:,7] >=32.3), (weather.iloc[:,7] <32.3) & (weather.iloc[:,7] >=30.5), (weather.iloc[:,7] <30.5) & (weather.iloc[:,7] >=27.8), weather.iloc[:,7] <27.8 ]
choices     = [ "Black", 'Red', 'Yellow', 'Green', 'White']

weather['Min Temp Flag'] = np.select(conditions, choices, default=np.nan)

weather['Min Temp Flag'].value_counts()
# Out:
# White    361
# nan        4
# Name: Min Temp Flag, dtype: int64

# %%
conditions  = [ weather.iloc[:,9] >33.3, (weather.iloc[:,9] <=33.3) & (weather.iloc[:,9] >=32.3), (weather.iloc[:,9] <32.3) & (weather.iloc[:,9] >=30.5), (weather.iloc[:,9] <30.5) & (weather.iloc[:,9] >=27.8), weather.iloc[:,9] <27.8 ]
choices     = [ "Black", 'Red', 'Yellow', 'Green', 'White']

weather['Mean Temp Flag'] = np.select(conditions, choices, default=np.nan)

weather['Mean Temp Flag'].value_counts()
# Out:
# White    355
# nan       10
# Name: Mean Temp Flag, dtype: int64

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(weather.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ### CHECKING WHICH ROWS HAS NULL VALUES CORRESPONDING TO COLUMNS

# %%
weather[weather.iloc[:,5].isnull()].index.tolist()
# Out:
# [100, 137, 141, 148, 157, 302, 310, 330]

# %%
weather[weather.iloc[:,7].isnull()].index.tolist()
# Out:
# [64, 141, 142, 157]

# %%
weather[weather.iloc[:,9].isnull()].index.tolist()
# Out:
# [64, 100, 137, 141, 142, 148, 157, 302, 310, 330]

# %% [markdown]
# ### DROPPING ROWS 141 and 157 AS THESE ROWS ARE EMPTY IN 3 COLUMNS

# %%
weather.drop(weather.index[[141,157]]).head()
# Out:
#   Date/Time  Year  Month  Day  Data Quality  Max Temp (Â°C) Max Temp Flag  \
# 0  1/1/2017  2017      1    1           NaN             3.1         White
# 1  1/2/2017  2017      1    2           NaN             5.5         White
# 2  1/3/2017  2017      1    3           NaN             4.8         White
# 3  1/4/2017  2017      1    4           NaN             3.8         White
# 4  1/5/2017  2017      1    5           NaN            -5.3         White
#
#    Min Temp (Â°C) Min Temp Flag  Mean Temp (Â°C)  ... Cool Deg Days (Â°C)  \
# 0            -0.5         White              1.3  ...                 0.0
# 1             0.7         White              3.1  ...                 0.0
# 2             2.4         White              3.6  ...                 0.0
# 3            -7.6         White             -1.9  ...                 0.0
# 4           -10.3         White             -7.8  ...                 0.0
#
#    Cool Deg Days Flag Total Rain Flag  Total Snow Flag Total Precip (mm)  \
# 0                 NaN               M                M               0.0
# 1                 NaN               M                M               0.0
# 2                 NaN               M                M              11.3
# 3                 NaN               M                M               0.6
# 4                 NaN               M                M               0.0
#
#   Total Precip Flag Snow on Grnd (cm)  Snow on Grnd Flag Dir of Max Gust Flag  \
# 0               NaN               3.0                NaN                    M
# 1               NaN               3.0                NaN                    M
# 2               NaN               1.0                NaN                    M
# 3               NaN               NaN                NaN                    M
# 4               NaN               NaN                NaN                    M
#
#    Spd of Max Gust Flag
# 0                     M
# 1                     M
# 2                     M
# 3                     M
# 4                     M
#
# [5 rows x 23 columns]

# %% [markdown]
# ### COOLING DEGREE DAYS
# Cooling degree-days for a given day are the number of degrees Celsius that the mean temperature is above 18 °C.
# If the temperature is equal to or less than 18 °C, then the number will be zero.
# For example, a day with a mean temperature of 20.5 °C has 2.5 cooling degree-days;
# a day with a mean temperature of 15.5 °C has zero cooling degree-days.
# Cooling degree-days are used primarily to estimate the air-conditioning requirements of buildings.
# REFERENCE: https://climate.weather.gc.ca/glossary_e.html accessed on: 26-Sep 2019
#
#
# There is no information on CDD or HDD flags. So, drop these columns.

# %%
to_drop = [weather.iloc[:,14], weather.iloc[:,12]]
#weather.drop(to_drop, inplace=True)
weather.head()
# Out:
#   Date/Time  Year  Month  Day  Data Quality  Max Temp (Â°C) Max Temp Flag  \
# 0  1/1/2017  2017      1    1           NaN             3.1         White
# 1  1/2/2017  2017      1    2           NaN             5.5         White
# 2  1/3/2017  2017      1    3           NaN             4.8         White
# 3  1/4/2017  2017      1    4           NaN             3.8         White
# 4  1/5/2017  2017      1    5           NaN            -5.3         White
#
#    Min Temp (Â°C) Min Temp Flag  Mean Temp (Â°C)  ... Cool Deg Days (Â°C)  \
# 0            -0.5         White              1.3  ...                 0.0
# 1             0.7         White              3.1  ...                 0.0
# 2             2.4         White              3.6  ...                 0.0
# 3            -7.6         White             -1.9  ...                 0.0
# 4           -10.3         White             -7.8  ...                 0.0
#
#    Cool Deg Days Flag Total Rain Flag  Total Snow Flag Total Precip (mm)  \
# 0                 NaN               M                M               0.0
# 1                 NaN               M                M               0.0
# 2                 NaN               M                M              11.3
# 3                 NaN               M                M               0.6
# 4                 NaN               M                M               0.0
#
#   Total Precip Flag Snow on Grnd (cm)  Snow on Grnd Flag Dir of Max Gust Flag  \
# 0               NaN               3.0                NaN                    M
# 1               NaN               3.0                NaN                    M
# 2               NaN               1.0                NaN                    M
# 3               NaN               NaN                NaN                    M
# 4               NaN               NaN                NaN                    M
#
#    Spd of Max Gust Flag
# 0                     M
# 1                     M
# 2                     M
# 3                     M
# 4                     M
#
# [5 rows x 23 columns]

# %%
weather.columns
# Out:
# Index(['Date/Time', 'Year', 'Month', 'Day', 'Data Quality', 'Max Temp (Â°C)',
#        'Max Temp Flag', 'Min Temp (Â°C)', 'Min Temp Flag', 'Mean Temp (Â°C)',
#        'Mean Temp Flag', 'Heat Deg Days (Â°C)', 'Heat Deg Days Flag',
#        'Cool Deg Days (Â°C)', 'Cool Deg Days Flag', 'Total Rain Flag',
#        'Total Snow Flag', 'Total Precip (mm)', 'Total Precip Flag',
#        'Snow on Grnd (cm)', 'Snow on Grnd Flag', 'Dir of Max Gust Flag',
#        'Spd of Max Gust Flag'],
#       dtype='object')

# %% [markdown]
# #### DROPPING OTHER FLAG COLUMNS WHICH ARE NOT REQUIRED

# %%
to_drop = [weather.iloc[:,16], weather.iloc[:,14]]
#weather.drop(to_drop, inplace=True, axis=1)

# %%
weather.columns
# Out:
# Index(['Date/Time', 'Year', 'Month', 'Day', 'Data Quality', 'Max Temp (Â°C)',
#        'Max Temp Flag', 'Min Temp (Â°C)', 'Min Temp Flag', 'Mean Temp (Â°C)',
#        'Mean Temp Flag', 'Heat Deg Days (Â°C)', 'Heat Deg Days Flag',
#        'Cool Deg Days (Â°C)', 'Cool Deg Days Flag', 'Total Rain Flag',
#        'Total Snow Flag', 'Total Precip (mm)', 'Total Precip Flag',
#        'Snow on Grnd (cm)', 'Snow on Grnd Flag', 'Dir of Max Gust Flag',
#        'Spd of Max Gust Flag'],
#       dtype='object')

# %%
weather[weather.iloc[:,11].isna()]
# Out:
#       Date/Time  Year  Month  Day  Data Quality  Max Temp (Â°C) Max Temp Flag  \
# 64     3/6/2017  2017      3    6           NaN             4.9         White
# 100   4/11/2017  2017      4   11           NaN             NaN           nan
# 137   5/18/2017  2017      5   18           NaN             NaN           nan
# 141   5/22/2017  2017      5   22           NaN             NaN           nan
# 142   5/23/2017  2017      5   23           NaN            21.8         White
# 148   5/29/2017  2017      5   29           NaN             NaN           nan
# 157    6/7/2017  2017      6    7           NaN             NaN           nan
# 302  10/30/2017  2017     10   30           NaN             NaN           nan
# 310   11/7/2017  2017     11    7           NaN             NaN           nan
# 330  11/27/2017  2017     11   27           NaN             NaN           nan
#
#      Min Temp (Â°C) Min Temp Flag  Mean Temp (Â°C)  ... Cool Deg Days (Â°C)  \
# 64              NaN           nan              NaN  ...                 NaN
# 100            11.3         White              NaN  ...                 NaN
# 137            18.4         White              NaN  ...                 NaN
# 141             NaN           nan              NaN  ...                 NaN
# 142             NaN           nan              NaN  ...                 NaN
# 148            14.7         White              NaN  ...                 NaN
# 157             NaN           nan              NaN  ...                 NaN
# 302             5.9         White              NaN  ...                 NaN
# 310             4.0         White              NaN  ...                 NaN
# 330             1.3         White              NaN  ...                 NaN
#
#      Cool Deg Days Flag Total Rain Flag  Total Snow Flag Total Precip (mm)  \
# 64                    M               M                M               NaN
# 100                   M               M                M               NaN
# 137                   M               M                M               NaN
# 141                   M               M                M               NaN
# 142                   M               M                M               NaN
# 148                   M               M                M               NaN
# 157                   M               M                M               NaN
# 302                   M               M                M               NaN
# 310                   M               M                M               NaN
# 330                   M               M                M               NaN
#
#     Total Precip Flag Snow on Grnd (cm)  Snow on Grnd Flag  \
# 64                  M               NaN                NaN
# 100                 M               NaN                NaN
# 137                 M               NaN                NaN
# 141                 M               NaN                NaN
# 142                 M               NaN                NaN
# 148                 M               NaN                NaN
# 157                 M               NaN                NaN
# 302                 M               NaN                NaN
# 310                 M               NaN                NaN
# 330                 M               NaN                NaN
#
#     Dir of Max Gust Flag  Spd of Max Gust Flag
# 64                     M                     M
# 100                    M                     M
# 137                    M                     M
# 141                    M                     M
# 142                    M                     M
# 148                    M                     M
# 157                    M                     M
# 302                    M                     M
# 310                    M                     M
# 330                    M                     M
#
# [10 rows x 23 columns]

# %% [markdown]
# Above output shows that Heat Degree Days has null values where almost all columns are unknown, except few.
# The available values in these rows only for Max or Min Temp, even not together.
# So, finding values for all coulmns based on these few values is not certain.
# So drop these rows.

# %%
weather.drop(weather.index[[64,100,137,142,148,302,310]], inplace= True)

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(weather.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ### DEALING WITH PRECIPIATION FLAG
# The millimetre (mm) is the unit of measurement of liquid precipitation and the vertical depth of water or water equivalent is express to the nearest 0.2 mm. Less than 0.2 mm is called a "Trace".
# https://climate.weather.gc.ca/glossary_e.html accessed on: 26 Sep 2019

# %%
conditions  = [ weather['Total Precip (mm)']<0.2, weather['Total Precip (mm)']>=0.2]  
choices     = [ '0', '1'] # 0 is for trace, 1 is for above trace

weather['Total Precip Flag'] = np.select(conditions, choices, default=np.nan)

# %%
weather['Total Precip Flag'].value_counts()
# Out:
# 0      210
# 1      140
# nan      8
# Name: Total Precip Flag, dtype: int64

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(weather.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# Well, most of the data is clean. However, still there are some missing values which could be cleaned in similar manner.
# This could be cleaned according to business requirement.
